# %%
from dotenv import load_dotenv
import os

# %%
load_dotenv(override=True)
# Out:
# True

# %%
# Check the key - if you're not using OpenAI, check whichever key you're using! Ollama doesn't need a key.
openai_api_key = os.getenv('OPENAI_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# OpenAI API Key exists and begins sk-proj-

# %%
from openai import OpenAI

openai = OpenAI()

# %%
# create a list of messages to send to the model
messages = [
    {"role": "user", "content": "What is 2 + 2?"}
]

# %%
response = openai.chat.completions.create(
    model="gpt-4.1-nano",
    messages=messages
)

print(response.choices[0].message.content)
# Out:
# 2 + 2 equals 4.

# %%
question = " Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [
    {"role": "user", "content": question}
]

# %%
response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages   
)

question = response.choices[0].message.content
print(question)
# Out:
# If two trains start from points A and B, 300 miles apart, heading toward each other at speeds of 60 mph and 40 mph respectively, and a bird flies back and forth between them at 90 mph until the trains meet, how far does the bird travel?

# %%
messages = [{"role": "user", "content": question}]

# %%
response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages   
)
answer = response.choices[0].message.content
print(answer)
# Out:
# Let's analyze the problem step by step:
#
# **Given:**
# - Distance between points A and B = 300 miles
# - Train from A speed = 60 mph
# - Train from B speed = 40 mph
# - Bird speed = 90 mph
#
# **Goal:**
# Find the total distance the bird travels between the trains until they meet.
#
# ---
#
# ### Step 1: Find the time until the trains meet
#
# The two trains are moving toward each other, so their relative speed is:
# \[
# 60 \text{ mph} + 40 \text{ mph} = 100 \text{ mph}
# \]
#
# The distance between them is 300 miles, so the time until they meet is:
# \[
# t = \frac{\text{distance}}{\text{relative speed}} = \frac{300 \text{ miles}}{100 \text{ mph}} = 3 \text{ hours}
# \]
#
# ---
#
# ### Step 2: Calculate the distance the bird travels
#
# The bird flies continuously at 90 mph until the trains meet.
#
# Since the time until the trains meet is 3 hours, the bird flies for 3 hours.
#
# Thus, the distance the bird travels is:
# \[
# d = \text{speed of bird} \times \text{time} = 90 \text{ mph} \times 3 \text{ hours} = 270 \text{ miles}
# \]
#
# ---
#
# ### **Final answer:**
#
# \[
# \boxed{270 \text{ miles}}
# \]
#
# The bird travels 270 miles back and forth before the trains meet.

# %%
from IPython.display import Markdown, display
display(Markdown(f"**Question:** {question}"))
display(Markdown(f"**Answer:** {answer}"))
# Out:
# **Question:** If two trains start from points A and B, 300 miles apart, heading toward each other at speeds of 60 mph and 40 mph respectively, and a bird flies back and forth between them at 90 mph until the trains meet, how far does the bird travel?
# **Answer:** Let's analyze the problem step by step:
#
# **Given:**
# - Distance between points A and B = 300 miles
# - Train from A speed = 60 mph
# - Train from B speed = 40 mph
# - Bird speed = 90 mph
#
# **Goal:**
# Find the total distance the bird travels between the trains until they meet.
#
# ---
#
# ### Step 1: Find the time until the trains meet
#
# The two trains are moving toward each other, so their relative speed is:
# \[
# 60 \text{ mph} + 40 \text{ mph} = 100 \text{ mph}
# \]
#
# The distance between them is 300 miles, so the time until they meet is:
# \[
# t = \frac{\text{distance}}{\text{relative speed}} = \frac{300 \text{ miles}}{100 \text{ mph}} = 3 \text{ hours}
# \]
#
# ---
#
# ### Step 2: Calculate the distance the bird travels
#
# The bird flies continuously at 90 mph until the trains meet.
#
# Since the time until the trains meet is 3 hours, the bird flies for 3 hours.
#
# Thus, the distance the bird travels is:
# \[
# d = \text{speed of bird} \times \text{time} = 90 \text{ mph} \times 3 \text{ hours} = 270 \text{ miles}
# \]
#
# ---
#
# ### **Final answer:**
#
# \[
# \boxed{270 \text{ miles}}
# \]
#
# The bird travels 270 miles back and forth before the trains meet.
